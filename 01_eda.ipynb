# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/raw/dataset.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (1470, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
df["Attrition"].value_counts(normalize=True) * 100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df.nunique().sort_values()
# Out:
# EmployeeCount                  1
# Over18                         1
# StandardHours                  1
# Attrition                      2
# OverTime                       2
# PerformanceRating              2
# Gender                         2
# BusinessTravel                 3
# Department                     3
# MaritalStatus                  3
# RelationshipSatisfaction       4
# StockOptionLevel               4
# JobSatisfaction                4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
categoricalColumns = df.select_dtypes(include="object").columns.tolist()
numericalColumns = df.select_dtypes(exclude="object").columns.tolist()

categoricalColumns, numericalColumns
# Out:
# (['Attrition',
#   'BusinessTravel',
#   'Department',
#   'EducationField',
#   'Gender',
#   'JobRole',
#   'MaritalStatus',
#   'Over18',
#   'OverTime'],
#  ['Age',
#   'DailyRate',
#   'DistanceFromHome',
#   'Education',
#   'EmployeeCount',
#   'EmployeeNumber',
#   'EnvironmentSatisfaction',
#   'HourlyRate',
#   'JobInvolvement',
#   'JobLevel',
#   'JobSatisfaction',
#   'MonthlyIncome',
#   'MonthlyRate',
#   'NumCompaniesWorked',
#   'PercentSalaryHike',
#   'PerformanceRating',
#   'RelationshipSatisfaction',
#   'StandardHours',
#   'StockOptionLevel',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'WorkLifeBalance',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager'])

# %%
TARGET_COL = "Attrition"

DROP_COLS = [
    "EmployeeCount",
    "EmployeeNumber",
    "Over18",
    "StandardHours"
]

CATEGORICAL_FEATURES = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "Gender",
    "JobRole",
    "MaritalStatus",
    "OverTime"
]

NUMERIC_FEATURES = []
for col in df.columns:
    if col not in CATEGORICAL_FEATURES and col not in DROP_COLS and col != TARGET_COL:
        NUMERIC_FEATURES.append(col)

df[NUMERIC_FEATURES]
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102                 1          2                        2
# 1      49        279                 8          1                        3
# 2      37       1373                 2          2                        4
# 3      33       1392                 3          4                        4
# 4      27        591                 2          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884                23          2                        3
# 1466   39        613                 6          1                        4
# 1467   27        155                 4          3                        2
# 1468   49       1023                 2          3                        4
# 1469   34        628                 8          3                        2
#
# ...

# %%
x = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL].map({"Yes":1, "No":0})

x = x.drop(columns=DROP_COLS)

# %%
x.shape, y.shape
# Out:
# ((1470, 30), (1470,))

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# For Linear Models
numericTransformerScaling = Pipeline(steps = [
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# %%
# For Tree Models(They Dont Require Feature Scaling)
numericTransformerNonScaling = Pipeline(steps = [
    ("imputer", SimpleImputer(strategy="median"))
])

# %%
categoricalTransformer = Pipeline(steps = [
    ("imputer", SimpleImputer(strategy= "most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# %%
preprocessingLinear = ColumnTransformer(
    transformers=[
        ("num", numericTransformerScaling, NUMERIC_FEATURES),
        ("cat", categoricalTransformer, CATEGORICAL_FEATURES)
    ]
)

# %%
preprocessingNonLinear = ColumnTransformer(
    transformers=[
        ("num", numericTransformerNonScaling, NUMERIC_FEATURES),
        ("cat", categoricalTransformer, CATEGORICAL_FEATURES)
    ]
)

# %%
import mlflow
import mlflow.sklearn

# %%
RANDOM_STATE = 42
EXPERIMENT_NAME = "Hr_Attrition_Classification"

# %%
mlflow.set_experiment(EXPERIMENT_NAME)
# Out:
# 2026/01/11 00:25:09 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/11 00:25:09 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/11 00:25:09 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/11 00:25:09 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/11 00:25:09 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/11 00:25:09 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/11 00:25:09 INFO mlflow.tracking.fluent: Experiment with name 'Hr_Attrition_Classification' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:c:/Users/Aman/OneDrive/Documents/GitHub/HR-ATTRITION/mlruns/1', creation_time=1768071309774, experiment_id='1', last_update_time=1768071309774, lifecycle_stage='active', name='Hr_Attrition_Classification', tags={}>

# %%
from sklearn.model_selection import train_test_split

xTrain, xTest, yTrain, yTest = train_test_split(
    x,
    y,
    test_size=0.2,
    stratify=y,
    random_state= RANDOM_STATE
)

xTrain.shape, xTest.shape , yTrain.shape, yTest.shape
# Out:
# ((1176, 30), (294, 30), (1176,), (294,))

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)
from sklearn.linear_model import LogisticRegression

# %%
with mlflow.start_run(run_name="logistic_baseline"):
    model = LogisticRegression(
        max_iter=1000,
        class_weight="balanced",
        random_state= RANDOM_STATE
    )

    pipeline = Pipeline(steps = [
        ("preprocessing", preprocessingLinear),
        ("model", model)
    ])

    pipeline.fit(xTrain, yTrain)

    yPredictions = pipeline.predict(xTest)
    yProbs = pipeline.predict_proba(xTest)[:, 1]

    mlflow.log_params(model.get_params())
    
    mlflow.log_metrics({
        "accuracy": accuracy_score(yTest, yPredictions),
        "precision": precision_score(yTest, yPredictions),
        "recall": recall_score(yTest, yPredictions),
        "f1": f1_score(yTest, yPredictions),
        "roc_auc": roc_auc_score(yTest, yProbs)
    })

# %%
with mlflow.start_run(run_name="logistic_l2_c_0.5"):
    model = LogisticRegression(
        max_iter=1000,
        C = 0.5,
        penalty= "l2",
        class_weight="balanced",
        random_state= RANDOM_STATE
    )

    pipeline = Pipeline(steps = [
        ("preprocessing", preprocessingLinear),
        ("model", model)
    ])

    pipeline.fit(xTrain, yTrain)

    yPredictions = pipeline.predict(xTest)
    yProbs = pipeline.predict_proba(xTest)[:, 1]

    mlflow.log_params(model.get_params())
    
    mlflow.log_metrics({
        "accuracy": accuracy_score(yTest, yPredictions),
        "precision": precision_score(yTest, yPredictions),
        "recall": recall_score(yTest, yPredictions),
        "f1": f1_score(yTest, yPredictions),
        "roc_auc": roc_auc_score(yTest, yProbs)
    })

    mlflow.sklearn.log_model(
        sk_model=pipeline,
        name="model"
    )
# Out:
# c:\Users\Aman\OneDrive\Documents\GitHub\HR-ATTRITION\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
with mlflow.start_run(run_name="rf_baseline"):
    model = RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        random_state=42,
        class_weight="balanced"
    )

    pipeline = Pipeline(steps = [
        ("preprocessing", preprocessingNonLinear),
        ("model", model)
    ])

    pipeline.fit(xTrain, yTrain)

    yPredictions = pipeline.predict(xTest)
    yProbs = pipeline.predict_proba(xTest)[:, 1]

    mlflow.log_params(model.get_params())
    
    mlflow.log_metrics({
        "accuracy": accuracy_score(yTest, yPredictions),
        "precision": precision_score(yTest, yPredictions),
        "recall": recall_score(yTest, yPredictions), 
        "f1": f1_score(yTest, yPredictions),
        "roc_auc": roc_auc_score(yTest, yProbs)
    })

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

RUN_ID = "2cb6d483c4244d9da564fc1c72ff12df"
MODEL_NAME = "hr_attrition_model"

mlflow.register_model(
    model_uri=f"runs:/{RUN_ID}/model",
    name=MODEL_NAME
)
# Out:
# 2026/01/11 00:26:23 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/11 00:26:23 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/11 00:26:23 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/11 00:26:23 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# Successfully registered model 'hr_attrition_model'.
# 2026/01/11 00:26:23 WARNING mlflow.tracking._model_registry.fluent: Run with id 2cb6d483c4244d9da564fc1c72ff12df has no artifacts at artifact path 'model', registering model based on models:/m-dfcde622f4ef4ae7967422c6e63d02f5 instead
# Created version '1' of model 'hr_attrition_model'.
# ...

# %%
client.set_registered_model_alias(
    name=MODEL_NAME,
    alias="Production",
    version=1
)
